# %% [markdown]
# # Importing csv file

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.read_csv("/Users/tanishachopra/Downloads/house_sale_data.csv")
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # ques1--> What is the distribution of sale prices?

# %%
# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Plotting the distribution of sale prices
plt.figure(figsize=(10, 6))
plt.hist(df['SalePrice'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Sale Prices')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques2--> How does the overall quality of houses correlate with their sale prices?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Selecting columns for analysis
quality_saleprice = df[['OverallQual', 'SalePrice']]

# Calculate the correlation coefficient
correlation = quality_saleprice.corr().iloc[0, 1]

# Plotting the relationship between OverallQual and SalePrice
plt.figure(figsize=(10, 6))
plt.scatter(quality_saleprice['OverallQual'], quality_saleprice['SalePrice'], color='skyblue')
plt.title('Overall Quality vs Sale Price')
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.grid(True)
plt.show()

print("Correlation coefficient between Overall Quality and Sale Price:", correlation)
# Out:
# Correlation coefficient between Overall Quality and Sale Price: 0.7909816005838053

# %% [markdown]
# # ques3--> What is the average sale price per neighborhood?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Calculate the average sale price per neighborhood
average_sale_price_per_neighborhood = df.groupby('Neighborhood')['SalePrice'].mean()

# Plotting the average sale price per neighborhood
plt.figure(figsize=(12, 6))
average_sale_price_per_neighborhood.plot(kind='bar', color='skyblue')
plt.title('Average Sale Price per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Average Sale Price')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ques4--> Is there a correlation between the size of the lot and the sale price?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Plotting the relationship between LotArea and SalePrice
plt.figure(figsize=(10, 6))
plt.scatter(df['LotArea'], df['SalePrice'], color='skyblue', alpha=0.6)
plt.title('LotArea vs SalePrice')
plt.xlabel('Lot Area')
plt.ylabel('Sale Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques5 --> How does the number of bedrooms correlate with the sale price?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Plotting the relationship between the number of bedrooms and SalePrice
plt.figure(figsize=(10, 6))
plt.scatter(df['BedroomAbvGr'], df['SalePrice'], color='skyblue', alpha=0.6)
plt.title('Number of Bedrooms vs Sale Price')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Sale Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques6 --> What is the distribution of the year built for the houses?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Plotting the distribution of the year built
plt.figure(figsize=(10, 6))
plt.hist(df['YearBuilt'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Year Built')
plt.xlabel('Year Built')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques7 --> Is there a trend in sale prices over the years?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Assuming your dataset is stored in a DataFrame named 'df'
# Load the dataset
df = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Calculate the average sale price for each year
average_sale_price_per_year = df.groupby('YearBuilt')['SalePrice'].mean()

# Plotting the trend in sale prices over the years
plt.figure(figsize=(10, 6))
plt.plot(average_sale_price_per_year.index, average_sale_price_per_year.values, color='skyblue')
plt.title('Trend in Sale Prices Over the Years')
plt.xlabel('Year Built')
plt.ylabel('Average Sale Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques8--> How does the presence of a fireplace affect the sale price?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Filter the dataset to include only 'Fireplaces' and 'SalePrice' columns
fireplace_saleprice_data = data[['Fireplaces', 'SalePrice']]

# Plot using box plot
plt.figure(figsize=(8, 6))
data.boxplot(column='SalePrice', by='Fireplaces', grid=False)
plt.title('Sale Price Distribution with and without Fireplaces')
plt.xlabel('Fireplaces')
plt.ylabel('Sale Price')
plt.xticks([1, 2], ['No Fireplace', 'With Fireplace'])
plt.show()

# %% [markdown]
# # ques9--> What is the average living area (GrLivArea) for each house style (HouseStyle)?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Filter the dataset to include only 'GrLivArea' and 'HouseStyle' columns
grlivarea_housestyle_data = data[['GrLivArea', 'HouseStyle']]

# Group the data by 'HouseStyle' and calculate the mean of 'GrLivArea'
average_grlivarea_by_housestyle = grlivarea_housestyle_data.groupby('HouseStyle')['GrLivArea'].mean().reset_index()

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='HouseStyle', y='GrLivArea', data=average_grlivarea_by_housestyle, palette='viridis')
plt.title('Average Living Area by House Style')
plt.xlabel('House Style')
plt.ylabel('Average Living Area')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ques10--> How does the presence of a pool affect the sale price?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Filter the dataset to include only 'PoolArea' and 'SalePrice' columns
pool_saleprice_data = data[['PoolArea', 'SalePrice']]

# Create a new column indicating whether the property has a pool or not
pool_saleprice_data['HasPool'] = pool_saleprice_data['PoolArea'].apply(lambda x: 'Yes' if x > 0 else 'No')

# Create a pivot table to get the average sale price for each presence of a pool
pivot_table = pool_saleprice_data.pivot_table(values='SalePrice', index='HasPool', aggfunc='mean')

# Plot using Seaborn's heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt=".0f", cbar=True)
plt.title('Average Sale Price by Presence of Pool')
plt.xlabel('Presence of Pool')
plt.ylabel('Sale Price')
plt.show()
# Out:
# /var/folders/gw/23cgzj014kd4fnxkp92fn40c0000gn/T/ipykernel_3896/3070812041.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pool_saleprice_data['HasPool'] = pool_saleprice_data['PoolArea'].apply(lambda x: 'Yes' if x > 0 else 'No')

# %% [markdown]
# # ques11--> Is there a correlation between the garage area and the sale price?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Filter the dataset to include only 'GarageArea' and 'SalePrice' columns
garage_saleprice_data = data[['GarageArea', 'SalePrice']]

# Plot using scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(garage_saleprice_data['GarageArea'], garage_saleprice_data['SalePrice'], alpha=0.5)
plt.title('Garage Area vs Sale Price')
plt.xlabel('Garage Area')
plt.ylabel('Sale Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # ques12--> What is the most common type of heating system (Heating) in the dataset?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Count occurrences of each heating system
heating_counts = data['Heating'].value_counts()

# Plot using bar chart
plt.figure(figsize=(10, 6))
heating_counts.plot(kind='bar', color='skyblue')
plt.title('Counts of Heating Systems')
plt.xlabel('Heating System')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ques13--> What is the average sale price per month (MoSold) or per year (YrSold)?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the dataset is stored in a CSV file named 'dataset.csv'
data = pd.read_csv('/Users/tanishachopra/Downloads/house_sale_data.csv')

# Extract month and year from 'MoSold' and 'YrSold' columns
data['MoSold'] = pd.to_datetime(data['MoSold'], format='%m').dt.month_name()
data['YearSold'] = pd.to_datetime(data['YrSold'], format='%Y')

# Group the data by month or year and calculate the average sale price
average_price_per_month = data.groupby('MoSold')['SalePrice'].mean()
average_price_per_year = data.groupby('YearSold')['SalePrice'].mean()

# Plot using line plot
plt.figure(figsize=(12, 6))

# Plot average sale price per month
plt.subplot(2, 1, 1)
average_price_per_month.plot(kind='line', marker='o', color='blue')
plt.title('Average Sale Price per Month')
plt.xlabel('Month')
plt.ylabel('Average Sale Price')

# Plot average sale price per year
plt.subplot(2, 1, 2)
average_price_per_year.plot(kind='line', marker='o', color='green')
plt.title('Average Sale Price per Year')
plt.xlabel('Year')
plt.ylabel('Average Sale Price')

plt.tight_layout()
plt.show()
